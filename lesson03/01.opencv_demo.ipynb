# %%
import matplotlib.pyplot as plt
import cv2

# %%
img1 = cv2.imread("./imgs/tree.jpg")  # png,jpg,jpeg
# print(img1) #像素矩陣，BGR

plt.imshow(img1)
plt.axis("off")
plt.show()

# %%
from IPython.display import Image

Image("./imgs/tree.jpg", width=600)

# %%
imga = cv2.imread("./imgs/tree.jpg")  # BGR
cv2.imshow("MYPIC", imga)
cv2.waitKey(0)  # 等待的時間, 0代表由使用者決定
cv2.destroyAllWindows()  # 清除視窗

# %%
print("全彩")
img1a = img1[:, :, ::-1]
# print(img1a)
plt.imshow(img1a)
plt.axis("off")
plt.show()
# Out:
# 全彩

# %%
img2 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img3a = cv2.cvtColor(img1a, cv2.COLOR_RGB2GRAY)
img3 = cv2.cvtColor(img1a, cv2.COLOR_BGR2GRAY)

# print('轉換為RGB')
# plt.imshow(img2)
# plt.axis('off')
# plt.show()

print("轉換為灰階")
plt.imshow(img3a, cmap="gray")
plt.axis("off")
plt.show()

plt.imshow(img3, cmap="gray")
plt.axis("off")
plt.show()
# print(img3)
# Out:
# 轉換為灰階

# %%
cv2.imwrite("tree_gray.jpg", img3)
# Out:
# True
