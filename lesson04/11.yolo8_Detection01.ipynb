# %% [markdown]
# https://ithelp.ithome.com.tw/articles/10311114

# %%
# !pip install ultralytics
# Out:
# ...
#      ---------------------------------------- 0.0/41.2 kB ? eta -:--:--
#      ---------------------------------------- 41.2/41.2 kB 1.9 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/793.6 kB ? eta -:--:--
#    ---------- ----------------------------- 215.0/793.6 kB 6.6 MB/s eta 0:00:01
#    -------------------------- ------------- 532.5/793.6 kB 6.7 MB/s eta 0:00:01
#    ---------------------------------------- 793.6/793.6 kB 8.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/159.7 MB ? eta -:--:--
#    ---------------------------------------- 1.9/159.7 MB 40.7 MB/s eta 0:00:04
#    - -------------------------------------- 5.3/159.7 MB 56.6 MB/s eta 0:00:03
#    -- ------------------------------------- 10.7/159.7 MB 73.1 MB/s eta 0:00:03
#    --- ----------------------------------- 14.6/159.7 MB 108.8 MB/s eta 0:00:02
#    --- ------------------------------------ 14.9/159.7 MB 72.6 MB/s eta 0:00:02
# ...

# %%
from ultralytics import YOLO

# %%
# !python -V
# Out:
# Python 3.11.10

# %%
# Load a model
model = YOLO("./yolov8n.pt")  # load a pretrained model (recommended for training)

# 預測:會將檢測結果輸出到run/detect/predict資料夾內
results = model("images/bus.jpg")

# 顯示物件類別
print(results[0].boxes.cls)
print()

# 顯示物件座標
print(results[0].boxes.xyxy)
# Out:
# image 1/1 /home/chesterxalan/github/Classwork/Classwork-PythonDLApplicationDevelopment/lesson04/images/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 95.7ms
# Speed: 4.4ms preprocess, 95.7ms inference, 145.7ms postprocess per image at shape (1, 3, 640, 480)
# tensor([ 5.,  0.,  0.,  0., 11.,  0.], device='cuda:0')
#
# tensor([[1.7249e+01, 2.3059e+02, 8.0152e+02, 7.6845e+02],
#         [4.8745e+01, 3.9926e+02, 2.4451e+02, 9.0251e+02],
#         [6.7027e+02, 3.8028e+02, 8.0986e+02, 8.7569e+02],
#         [2.2140e+02, 4.0579e+02, 3.4472e+02, 8.5740e+02],
#         [6.4180e-02, 2.5465e+02, 3.2287e+01, 3.2504e+02],
#         [0.0000e+00, 5.5101e+02, 6.7115e+01, 8.7392e+02]], device='cuda:0')

# %%
from PIL import Image
# import cv2

# from PIL
im1 = Image.open("./images/bus.jpg")  # ./bus.jpg
# save=True：存檔
results = model.predict(source=im1, save=True)
# Out:
# 0: 640x480 4 persons, 1 bus, 1 stop sign, 16.4ms
# Speed: 2.6ms preprocess, 16.4ms inference, 2.5ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /home/chesterxalan/github/Classwork/Classwork-PythonDLApplicationDevelopment/runs/detect/predict

# %%
# 資料夾重整後檢視圖片
# !ls ../runs/detect/predict
# Out:
# bus.jpg

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# 重新整理資料後,注意路徑名稱
image0 = plt.imread("../runs/detect/predict/bus.jpg")
plt.imshow(image0)
plt.show()

# %%
# 預測整個資料夾:
# results = model.predict(source="dogs", save=True)#, show=True
# 預測影片:
results = model.predict(source="./images/美河市1.mp4", show=True, save=True)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/294) /home/chesterxalan/github/Classwork/Classwork-PythonDLApplicationDevelopment/lesson04/images/美河市1.mp4: 640x384 7 persons, 183.9ms
# video 1/1 (frame 2/294) /home/chesterxalan/github/Classwork/Classwork-PythonDLApplicationDevelopment/lesson04/images/美河市1.mp4: 640x384 10 persons, 9.6ms
# ...
